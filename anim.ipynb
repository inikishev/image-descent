# %%
x = [0, 1, 2 ,3 , 4, 5, 6,7 ,8]
y = [0, 3, 2 ,4 , 3, 6, 5,8 ,7]
c = [0,1, 2, 3, 4, 5, 6, 7, 8, ]
import matplotlib.pyplot as plt
plt.plot(x,y)
plt.scatter(x,y,c=c)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation
from IPython.display import HTML, display
plt.ioff() #needed so the second time you run it you get only single plot

fig, ax = plt.subplots()
line = ax.plot(x, y, color='k')[0]
scatter = ax.scatter(x, y, c=c)

def update(num):
    line.set_data(x[:num], y[:num])
    return line,

ani = animation.FuncAnimation(fig, update, len(x),
                              interval=1000, blit=True)
out = HTML(ani.to_html5_video())
plt.close()
plt.clf()
out
# Out:
# <video width="640" height="480" controls autoplay loop>
#   <source type="video/mp4" src="...">
#   Your browser does not support the video tag.
# </video>

# %%
plt.clf()

# %%
plt.plot(x,y)
plt.scatter(x,y,c=c)
plt.show()

# %%
import celluloid
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [6], line 5
#       2 from matplotlib.animation import TimedAnimation
#       3 fig = plt.figure()
# ----> 5 anim = TimedAnimation(fig, interval=1000)
#
# File d:\miniconda3\envs\pytorch311\Lib\site-packages\matplotlib\animation.py:1417, in TimedAnimation.__init__(self, fig, interval, repeat_delay, repeat, event_source, *args, **kwargs)
#    1415 if event_source is None:
#    1416     event_source = fig.canvas.new_timer(interval=self._interval)
# -> 1417 super().__init__(fig, event_source=event_source, *args, **kwargs)
#
# File d:\miniconda3\envs\pytorch311\Lib\site-packages\matplotlib\animation.py:876, in Animation.__init__(self, fig, event_source, blit)
#     870 self._blit = blit and fig.canvas.supports_blit
#     872 # These are the basics of the animation.  The frame sequence represents
#     873 # information for each frame of the animation and depends on how the
#     874 # drawing is handled by the subclasses. The event source fires events
#     875 # that cause the frame sequence to be iterated.
# --> 876 self.frame_seq = self.new_frame_seq()
#     877 self.event_source = event_source
#     879 # Instead of starting the event source now, we connect to the figure's
#     880 # draw_event, so that we only start once the figure has been drawn.
#
# File d:\miniconda3\envs\pytorch311\Lib\site-packages\matplotlib\animation.py:1129, in Animation.new_frame_seq(self)
#    1127 """Return a new sequence of frame information."""
#    1128 # Default implementation is just an iterator over self._framedata
# -> 1129 return iter(self._framedata)
#
# AttributeError: 'TimedAnimation' object has no attribute '_framedata'
