# %%
from image_descent.surfaces import *
rosenbrock.plot(levels=20)
# Out:
# (<Figure size 640x480 with 2 Axes>, <Axes: title={'center': 'Loss landscape'}>)

# %%
rastrigin.plot(levels=0)
# Out:
# (<Figure size 640x480 with 2 Axes>, <Axes: title={'center': 'Loss landscape'}>)

# %%
ackley.plot(levels=10)
# Out:
# (<Figure size 640x480 with 2 Axes>, <Axes: title={'center': 'Loss landscape'}>)

# %%
sphere.plot()
# Out:
# (<Figure size 640x480 with 2 Axes>, <Axes: title={'center': 'Loss landscape'}>)

# %%
beale.plot(levels=100)
# Out:
# (<Figure size 640x480 with 2 Axes>, <Axes: title={'center': 'Loss landscape'}>)

# %%
booth.plot()
# Out:
# (<Figure size 640x480 with 2 Axes>, <Axes: title={'center': 'Loss landscape'}>)

# %%
goldstein_prince.plot()
# Out:
# (<Figure size 640x480 with 2 Axes>, <Axes: title={'center': 'Loss landscape'}>)
