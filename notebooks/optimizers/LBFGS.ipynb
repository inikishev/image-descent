# %%
import torch
from image_descent.function_descent import FunctionDescent2D
from image_descent.surfaces import *

# %%
descent = FunctionDescent2D(rosenbrock)
optimizer = torch.optim.LBFGS(descent.parameters(), 1e-1)
for i in range(100):
    def closure():
        optimizer.zero_grad()
        loss = descent.step()
        loss.backward()
        return loss
    loss = optimizer.step(closure)
    if i%10==0: print(i, loss, end='       \r')
descent.plot_path()
# Out:
# 90 tensor(4.7775e-10, grad_fn=<DivBackward0>)       tensor(4.7775e-10, grad_fn=<DivBackward0>)

# %%
descent = FunctionDescent2D(rastrigin)
optimizer = torch.optim.LBFGS(descent.parameters(), 1)
for i in range(100):
    def closure():
        optimizer.zero_grad()
        loss = descent.step()
        loss.backward()
        return loss
    loss = optimizer.step(closure)
    if i%10==0: print(i, loss, end='       \r')
descent.plot_path(levels=0)
# Out:
# 90 tensor(0.0617, grad_fn=<DivBackward0>)

# %%
descent = FunctionDescent2D(ackley)
optimizer = torch.optim.LBFGS(descent.parameters(), 1)
for i in range(100):
    def closure():
        optimizer.zero_grad()
        loss = descent.step()
        loss.backward()
        return loss
    loss = optimizer.step(closure)
    if i%10==0: print(i, loss, end='       \r')
descent.plot_path(levels=0)
# Out:
# 90 tensor(0.8954, grad_fn=<DivBackward0>)

# %%
descent = FunctionDescent2D(beale)
optimizer = torch.optim.LBFGS(descent.parameters(), 1)
for i in range(100):
    def closure():
        optimizer.zero_grad()
        loss = descent.step()
        loss.backward()
        return loss
    loss = optimizer.step(closure)
    if i%10==0: print(i, loss, end='       \r')
descent.plot_path()
# Out:
# 90 tensor(-2.0371e-08, grad_fn=<DivBackward0>)

# %%
descent = FunctionDescent2D(booth)
optimizer = torch.optim.LBFGS(descent.parameters(), 1)
for i in range(100):
    def closure():
        optimizer.zero_grad()
        loss = descent.step()
        loss.backward()
        return loss
    loss = optimizer.step(closure)
    if i%10==0: print(i, loss, end='       \r')
descent.plot_path()
# Out:
# 90 tensor(5.0839e-14, grad_fn=<DivBackward0>)

# %%
descent = FunctionDescent2D(booth)
optimizer = torch.optim.LBFGS(descent.parameters(), 0.5)
for i in range(100):
    def closure():
        optimizer.zero_grad()
        loss = descent.step()
        loss.backward()
        return loss
    loss = optimizer.step(closure)
    if i%10==0: print(i, loss, end='       \r')
descent.plot_path()
# Out:
# 90 tensor(4.7380e-10, grad_fn=<DivBackward0>)

# %%
descent = FunctionDescent2D(goldstein_prince)
optimizer = torch.optim.LBFGS(descent.parameters(), 1)
for i in range(100):
    def closure():
        optimizer.zero_grad()
        loss = descent.step()
        loss.backward()
        return loss
    loss = optimizer.step(closure)
    if i%10==0: print(i, loss, end='       \r')
descent.plot_path()
# Out:
# 90 tensor(5.9974e-06, grad_fn=<DivBackward0>)

# %%
descent = FunctionDescent2D(sphere)
optimizer = torch.optim.LBFGS(descent.parameters(), 1)
for i in range(100):
    def closure():
        optimizer.zero_grad()
        loss = descent.step()
        loss.backward()
        return loss
    loss = optimizer.step(closure)
    if i%10==0: print(i, loss, end='       \r')
descent.plot_path()
# Out:
# 90 tensor(1.5721e-13, grad_fn=<DivBackward0>)

# %%
descent = FunctionDescent2D(cross)
optimizer = torch.optim.LBFGS(descent.parameters(), 0.2)
for i in range(100):
    def closure():
        optimizer.zero_grad()
        loss = descent.step()
        loss.backward()
        return loss
    loss = optimizer.step(closure)
    if i%10==0: print(i, loss, end='       \r')
descent.plot_path()
# Out:
# 90 tensor(-2.8590e-05, grad_fn=<DivBackward0>)
