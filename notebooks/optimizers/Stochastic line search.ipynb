# %% [markdown]
# # Stochastic line search
# Source: https://github.com/IssamLaradji/sls

# %%
from stuff.found.adasls import Sls
from image_descent.function_descent import FunctionDescent2D
from image_descent.surfaces import *

# %%
descent = FunctionDescent2D(rosenbrock)
optimizer = Sls(descent.parameters(), n_batches_per_epoch=5, init_step_size=1)
for i in range(100):
    def closure():
        optimizer.zero_grad()
        loss = descent.step()
        #loss.backward()
        return loss
    loss = optimizer.step(closure)
    if i%10==0: print(i, loss, end='       \r')
descent.plot_path()
# Out:
# 90 tensor(8.6923e-05, grad_fn=<DivBackward0>)

# %%
descent = FunctionDescent2D(rastrigin)
optimizer = Sls(descent.parameters(), n_batches_per_epoch=5, init_step_size=3)
for i in range(100):
    def closure():
        optimizer.zero_grad()
        loss = descent.step()
        #loss.backward()
        return loss
    loss = optimizer.step(closure)
    if i%10==0: print(i, loss, end='       \r')
descent.plot_path(levels=0)
# Out:
# 90 tensor(0.1111, grad_fn=<DivBackward0>)

# %%
descent = FunctionDescent2D(ackley)
optimizer = Sls(descent.parameters(), n_batches_per_epoch=5, init_step_size=500)
for i in range(100):
    def closure():
        optimizer.zero_grad()
        loss = descent.step()
        #loss.backward()
        return loss
    loss = optimizer.step(closure)
    if i%10==0: print(i, loss, end='       \r')
descent.plot_path(levels=0)
# Out:
# 90 tensor(0.8908, grad_fn=<DivBackward0>)

# %%
descent = FunctionDescent2D(beale)
optimizer = Sls(descent.parameters(), n_batches_per_epoch=5, init_step_size=4)
for i in range(100):
    def closure():
        optimizer.zero_grad()
        loss = descent.step()
        #loss.backward()
        return loss
    loss = optimizer.step(closure)
    if i%10==0: print(i, loss, end='       \r')
descent.plot_path()
# Out:
# 90 tensor(7.9586e-06, grad_fn=<DivBackward0>)

# %%
descent = FunctionDescent2D(booth)
optimizer = Sls(descent.parameters(), n_batches_per_epoch=5, init_step_size=10)
for i in range(100):
    def closure():
        optimizer.zero_grad()
        loss = descent.step()
        #loss.backward()
        return loss
    loss = optimizer.step(closure)
    if i%10==0: print(i, loss, end='       \r')
descent.plot_path()
# Out:
# 90 tensor(5.9605e-15, grad_fn=<DivBackward0>)

# %%
descent = FunctionDescent2D(goldstein_prince)
optimizer = Sls(descent.parameters(), n_batches_per_epoch=5, init_step_size=10)
for i in range(100):
    def closure():
        optimizer.zero_grad()
        loss = descent.step()
        #loss.backward()
        return loss
    loss = optimizer.step(closure)
    if i%10==0: print(i, loss, end='       \r')
descent.plot_path()
# Out:
# 90 tensor(5.9972e-06, grad_fn=<DivBackward0>)

# %%
descent = FunctionDescent2D(sphere)
optimizer = Sls(descent.parameters(), n_batches_per_epoch=5, init_step_size=10)
for i in range(100):
    def closure():
        optimizer.zero_grad()
        loss = descent.step()
        #loss.backward()
        return loss
    loss = optimizer.step(closure)
    if i%10==0: print(i, loss, end='       \r')
descent.plot_path()
# Out:
# 90 tensor(7.7832e-16, grad_fn=<DivBackward0>)

# %%
descent = FunctionDescent2D(cross)
optimizer = Sls(descent.parameters(), n_batches_per_epoch=10, init_step_size=1)
for i in range(100):
    def closure():
        optimizer.zero_grad()
        loss = descent.step()
        #loss.backward()
        return loss
    loss = optimizer.step(closure)
    if i%10==0: print(i, loss, end='       \r')
descent.plot_path()
# Out:
# 90 tensor(0.2497, grad_fn=<DivBackward0>)
