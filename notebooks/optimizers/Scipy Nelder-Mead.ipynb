# %% [markdown]
# # scipy Nelder-Mead
# Sources:
# - https://github.com/rfeinman/pytorch-minimize
# - https://github.com/scipy/scipy

# %%
from torchmin.optim.scipy_minimizer import ScipyMinimizer
from image_descent.function_descent import FunctionDescent2D
from image_descent.surfaces import *

# %%
descent = FunctionDescent2D(rosenbrock)
optimizer = ScipyMinimizer(descent.parameters(), method = 'Nelder-Mead')
for i in range(10):
    def closure():
        optimizer.zero_grad()
        loss = descent.step()
        loss.backward()
        return loss
    loss = optimizer.step(closure)
    print(i, loss, end='       \r')
descent.plot_path()
# Out:
# d:\miniconda3\envs\pytorch311\Lib\site-packages\scipy\optimize\_minimize.py:560: RuntimeWarning: Method nelder-mead does not use gradient information (jac).
#   warn('Method %s does not use gradient information (jac).' % method,
# 9 tensor(2.4496e-13)

# %%
descent = FunctionDescent2D(rastrigin)
optimizer = ScipyMinimizer(descent.parameters(), method = 'Nelder-Mead')
for i in range(100):
    def closure():
        optimizer.zero_grad()
        loss = descent.step()
        loss.backward()
        return loss
    loss = optimizer.step(closure)
    print(i, loss, end='       \r')
descent.plot_path(levels=0)
# Out:
# 99 tensor(0.5062)       tensor(0.5062)

# %%
descent = FunctionDescent2D(ackley)
optimizer = ScipyMinimizer(descent.parameters(), method = 'Nelder-Mead')
for i in range(10):
    def closure():
        optimizer.zero_grad()
        loss = descent.step()
        loss.backward()
        return loss
    loss = optimizer.step(closure)
    print(i, loss, end='       \r')
descent.plot_path(levels=0)
# Out:
# 9 tensor(0.8959)

# %%
descent = FunctionDescent2D(beale)
optimizer = ScipyMinimizer(descent.parameters(), method = 'Nelder-Mead')
for i in range(10):
    def closure():
        optimizer.zero_grad()
        loss = descent.step()
        loss.backward()
        return loss
    loss = optimizer.step(closure)
    print(i, loss, end='       \r')
descent.plot_path()
# Out:
# 9 tensor(2.4804e-06)

# %%
descent = FunctionDescent2D(booth)
optimizer = ScipyMinimizer(descent.parameters(), method = 'Nelder-Mead')
for i in range(10):
    def closure():
        optimizer.zero_grad()
        loss = descent.step()
        loss.backward()
        return loss
    loss = optimizer.step(closure)
    print(i, loss, end='       \r')
descent.plot_path()
# Out:
# 9 tensor(4.7263e-13)

# %%
descent = FunctionDescent2D(goldstein_prince)
optimizer = ScipyMinimizer(descent.parameters(), method = 'Nelder-Mead')
for i in range(10):
    def closure():
        optimizer.zero_grad()
        loss = descent.step()
        loss.backward()
        return loss
    loss = optimizer.step(closure)
    print(i, loss, end='       \r')
descent.plot_path()
# Out:
# 9 tensor(5.9972e-06)

# %%
descent = FunctionDescent2D(sphere)
optimizer = ScipyMinimizer(descent.parameters(), method = 'Nelder-Mead')
for i in range(10):
    def closure():
        optimizer.zero_grad()
        loss = descent.step()
        loss.backward()
        return loss
    loss = optimizer.step(closure)
    print(i, loss, end='       \r')
descent.plot_path()
# Out:
# 9 tensor(3.5486e-11)

# %%
descent = FunctionDescent2D(cross)
optimizer = ScipyMinimizer(descent.parameters(), method = 'Nelder-Mead')
for i in range(10):
    def closure():
        optimizer.zero_grad()
        loss = descent.step()
        loss.backward()
        return loss
    loss = optimizer.step(closure)
    print(i, loss, end='       \r')
descent.plot_path()
# Out:
# 9 tensor(0.0005)
