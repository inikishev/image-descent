# %% [markdown]
# # Hyperfast
# Source: https://github.com/OPTAMI/OPTAMI

# %%
from stuff.found.OPTAMI.higher_order import Hyperfast
from image_descent.function_descent import FunctionDescent2D
from image_descent.surfaces import *

# %%
descent = FunctionDescent2D(rosenbrock)
optimizer = Hyperfast(descent.parameters(), L = 3e-1, verbose=False)
for i in range(3):
    def closure():
        optimizer.zero_grad()
        loss = descent.step()
        #loss.backward()
        return loss
    loss = optimizer.step(closure)
    if i%10==0: print(i, loss, end='       \r')
descent.plot_path()
# Out:
# 0 None

# %%
descent = FunctionDescent2D(rastrigin)
optimizer = Hyperfast(descent.parameters(), L = 1, verbose=False)
for i in range(1):
    def closure():
        optimizer.zero_grad()
        loss = descent.step()
        #loss.backward()
        return loss
    loss = optimizer.step(closure)
    print(i, loss, end='       \r')
descent.plot_path(levels=0)
# Out:
# 0 None

# %%
descent = FunctionDescent2D(ackley)
optimizer = Hyperfast(descent.parameters(), L = 1e-6, verbose=False)
for i in range(1):
    def closure():
        optimizer.zero_grad()
        loss = descent.step()
        #loss.backward()
        return loss
    loss = optimizer.step(closure)
    if i%10==0: print(i, loss, end='       \r')
descent.plot_path(levels=0)
# Out:
# 0 None

# %%
descent = FunctionDescent2D(beale)
optimizer = Hyperfast(descent.parameters(), L = 5, verbose=False)
for i in range(10):
    def closure():
        optimizer.zero_grad()
        loss = descent.step()
        #loss.backward()
        return loss
    loss = optimizer.step(closure)
    print(i, loss, end='       \r')
descent.plot_path()
# Out:
# 9 None

# %%
descent = FunctionDescent2D(booth)
optimizer = Hyperfast(descent.parameters(), L = 1e-16, verbose=False)
for i in range(1):
    def closure():
        optimizer.zero_grad()
        loss = descent.step()
        #loss.backward()
        return loss
    loss = optimizer.step(closure)
    if i%10==0: print(i, loss, end='       \r')
descent.plot_path()
# Out:
# 0 None

# %%
descent = FunctionDescent2D(goldstein_prince)
optimizer = Hyperfast(descent.parameters(), L = 3e-2, verbose=False)
for i in range(10):
    def closure():
        optimizer.zero_grad()
        loss = descent.step()
        #loss.backward()
        return loss
    loss = optimizer.step(closure)
    print(i, loss, end='       \r')
descent.plot_path()
# Out:
# 9 None

# %%
descent = FunctionDescent2D(sphere)
optimizer = Hyperfast(descent.parameters(), L = 1e-6, verbose=False)
for i in range(1):
    def closure():
        optimizer.zero_grad()
        loss = descent.step()
        #loss.backward()
        return loss
    loss = optimizer.step(closure)
    print(i, loss, end='       \r')
descent.plot_path()
# Out:
# 0 None

# %%
descent = FunctionDescent2D(cross)
optimizer = Hyperfast(descent.parameters(), L = 10, verbose=False)
for i in range(1):
    def closure():
        optimizer.zero_grad()
        loss = descent.step()
        #loss.backward()
        return loss
    loss = optimizer.step(closure)
    print(i, loss, end='       \r')
descent.plot_path()
# Out:
# 0 None
