# %%
from glio.optim.randomsearch import RandomWalk2
from image_descent.function_descent import FunctionDescent2D
from image_descent.surfaces import *

# %%
descent = FunctionDescent2D(rosenbrock)
optimizer = RandomWalk2(descent.parameters(), 1e-1)
for i in range(100):
    @torch.no_grad
    def closure():
        #optimizer.zero_grad()
        loss = descent.step()
        #loss.backward()
        return loss
    loss = optimizer.step(closure)
    if i%10==0: print(i, loss, end='       \r')
descent.plot_path()
# Out:
# 90 tensor(0.0002, grad_fn=<DivBackward0>)

# %%
descent = FunctionDescent2D(rosenbrock)
optimizer = RandomWalk2(descent.parameters(), 1e-2)
for i in range(10000):
    @torch.no_grad
    def closure():
        #optimizer.zero_grad()
        loss = descent.step()
        #loss.backward()
        return loss
    loss = optimizer.step(closure)
    if i%10==0: print(i, loss, end='       \r')
descent.plot_path()
# Out:
# 9990 tensor(0.0001, grad_fn=<DivBackward0>)           tensor(0.0001, grad_fn=<DivBackward0>)       tensor(0.0002, grad_fn=<DivBackward0>)       tensor(4.6107e-05, grad_fn=<DivBackward0>)       tensor(6.5955e-05, grad_fn=<DivBackward0>)

# %%
descent = FunctionDescent2D(rastrigin)
optimizer = RandomWalk2(descent.parameters(), 0.5)
for i in range(100):
    @torch.no_grad
    def closure():
        #optimizer.zero_grad()
        loss = descent.step()
        #loss.backward()
        return loss
    loss = optimizer.step(closure)
    if i%10==0: print(i, loss, end='       \r')
descent.plot_path(levels=0)
# Out:
# 90 tensor(0.3403, grad_fn=<DivBackward0>)

# %%
descent = FunctionDescent2D(rastrigin)
optimizer = RandomWalk2(descent.parameters(), 3e-1)
for i in range(10000):
    @torch.no_grad
    def closure():
        #optimizer.zero_grad()
        loss = descent.step()
        #loss.backward()
        return loss
    loss = optimizer.step(closure)
    if i%10==0: print(i, loss, end='       \r')
descent.plot_path(levels=0)
# Out:
# 9990 tensor(0.1526, grad_fn=<DivBackward0>)       tensor(0.5961, grad_fn=<DivBackward0>)

# %%
descent = FunctionDescent2D(ackley)
optimizer = RandomWalk2(descent.parameters(), 3)
for i in range(100):
    @torch.no_grad
    def closure():
        #optimizer.zero_grad()
        loss = descent.step()
        #loss.backward()
        return loss
    loss = optimizer.step(closure)
    if i%10==0: print(i, loss, end='       \r')
descent.plot_path(levels=0)
# Out:
# 90 tensor(0.9444, grad_fn=<DivBackward0>)

# %%
descent = FunctionDescent2D(ackley)
optimizer = RandomWalk2(descent.parameters(), 0.5)
for i in range(10000):
    @torch.no_grad
    def closure():
        #optimizer.zero_grad()
        loss = descent.step()
        #loss.backward()
        return loss
    loss = optimizer.step(closure)
    if i%10==0: print(i, loss, end='       \r')
descent.plot_path(levels=0)
# Out:
# 9990 tensor(0.9511)       tensor(0.9811)       tensor(0.9686)

# %%
descent = FunctionDescent2D(beale)
optimizer = RandomWalk2(descent.parameters(), 3e-1)
for i in range(100):
    @torch.no_grad
    def closure():
        #optimizer.zero_grad()
        loss = descent.step()
        #loss.backward()
        return loss
    loss = optimizer.step(closure)
    if i%10==0: print(i, loss, end='       \r')
descent.plot_path()
# Out:
# 90 tensor(6.2717e-06)

# %%
descent = FunctionDescent2D(beale)
optimizer = RandomWalk2(descent.parameters(), 1e-1)
for i in range(10000):
    @torch.no_grad
    def closure():
        #optimizer.zero_grad()
        loss = descent.step()
        #loss.backward()
        return loss
    loss = optimizer.step(closure)
    if i%10==0: print(i, loss, end='       \r')
descent.plot_path()
# Out:
# 9990 tensor(0.0011)

# %%
descent = FunctionDescent2D(booth)
optimizer = RandomWalk2(descent.parameters(), 5e-1)
for i in range(100):
    @torch.no_grad
    def closure():
        #optimizer.zero_grad()
        loss = descent.step()
        #loss.backward()
        return loss
    loss = optimizer.step(closure)
    if i%10==0: print(i, loss, end='       \r')
descent.plot_path()
# Out:
# 90 tensor(0.0201)

# %%
descent = FunctionDescent2D(booth)
optimizer = RandomWalk2(descent.parameters(), 2e-1)
for i in range(10000):
    @torch.no_grad
    def closure():
        #optimizer.zero_grad()
        loss = descent.step()
        #loss.backward()
        return loss
    loss = optimizer.step(closure)
    if i%10==0: print(i, loss, end='       \r')
descent.plot_path()
# Out:
# 9990 tensor(6.6853e-06)       tensor(0.0004)       tensor(8.8516e-05)

# %%
descent = FunctionDescent2D(goldstein_prince)
optimizer = RandomWalk2(descent.parameters(), 1e-1)
for i in range(100):
    @torch.no_grad
    def closure():
        #optimizer.zero_grad()
        loss = descent.step()
        #loss.backward()
        return loss
    loss = optimizer.step(closure)
    if i%10==0: print(i, loss, end='       \r')
descent.plot_path()
# Out:
# 90 tensor(8.6861e-06)

# %%
descent = FunctionDescent2D(goldstein_prince)
optimizer = RandomWalk2(descent.parameters(), 1e-2)
for i in range(10000):
    @torch.no_grad
    def closure():
        #optimizer.zero_grad()
        loss = descent.step()
        #loss.backward()
        return loss
    loss = optimizer.step(closure)
    if i%10==0: print(i, loss, end='       \r')
descent.plot_path()
# Out:
# 9990 tensor(-3.9991e-08)       ensor(-3.8617e-08)       tensor(-3.8495e-08)       tensor(9.7961e-09)       tensor(-3.8358e-08)       tensor(-3.8360e-08)       tensor(-3.9484e-08)
