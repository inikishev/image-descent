# %% [markdown]
# # Scipy SLSQP
# Sources:
# - https://github.com/rfeinman/pytorch-minimize
# - https://github.com/scipy/scipy

# %%
from torchmin.optim.scipy_minimizer import ScipyMinimizer
from image_descent.function_descent import FunctionDescent2D
from image_descent.surfaces import *

# %%
descent = FunctionDescent2D(rosenbrock)
optimizer = ScipyMinimizer(descent.parameters(), method = 'SLSQP')
for i in range(100):
    def closure():
        optimizer.zero_grad()
        loss = descent.step()
        loss.backward()
        return loss
    loss = optimizer.step(closure)
    print(i, loss, end='       \r')
descent.plot_path()
# Out:
# 99 tensor(7.3008e-07)

# %%
descent = FunctionDescent2D(rastrigin)
optimizer = ScipyMinimizer(descent.parameters(), method = 'SLSQP')
for i in range(100):
    def closure():
        optimizer.zero_grad()
        loss = descent.step()
        loss.backward()
        return loss
    loss = optimizer.step(closure)
    print(i, loss, end='       \r')
descent.plot_path(levels=0)
# Out:
# 99 tensor(0.3087)

# %%
descent = FunctionDescent2D(ackley)
optimizer = ScipyMinimizer(descent.parameters(), method = 'SLSQP')
for i in range(100):
    def closure():
        optimizer.zero_grad()
        loss = descent.step()
        loss.backward()
        return loss
    loss = optimizer.step(closure)
    print(i, loss, end='       \r')
descent.plot_path(levels=0)
# Out:
# 99 tensor(0.8954)

# %%
descent = FunctionDescent2D(beale)
optimizer = ScipyMinimizer(descent.parameters(), method = 'SLSQP')
for i in range(100):
    def closure():
        optimizer.zero_grad()
        loss = descent.step()
        loss.backward()
        return loss
    loss = optimizer.step(closure)
    print(i, loss, end='       \r')
descent.plot_path()
# Out:
# 99 tensor(5.5984e-06)

# %%
descent = FunctionDescent2D(booth)
optimizer = ScipyMinimizer(descent.parameters(), method = 'SLSQP')
for i in range(100):
    def closure():
        optimizer.zero_grad()
        loss = descent.step()
        loss.backward()
        return loss
    loss = optimizer.step(closure)
    print(i, loss, end='       \r')
descent.plot_path()
# Out:
# 99 tensor(8.7654e-17)       tensor(8.7654e-17)

# %%
descent = FunctionDescent2D(goldstein_prince)
optimizer = ScipyMinimizer(descent.parameters(), method = 'SLSQP')
for i in range(100):
    def closure():
        optimizer.zero_grad()
        loss = descent.step()
        loss.backward()
        return loss
    loss = optimizer.step(closure)
    print(i, loss, end='       \r')
descent.plot_path()
# Out:
# 99 tensor(7.1558e-06)

# %%
descent = FunctionDescent2D(sphere)
optimizer = ScipyMinimizer(descent.parameters(), method = 'SLSQP')
for i in range(100):
    def closure():
        optimizer.zero_grad()
        loss = descent.step()
        loss.backward()
        return loss
    loss = optimizer.step(closure)
    print(i, loss, end='       \r')
descent.plot_path()
# Out:
# 99 tensor(1.1612e-16)

# %%
descent = FunctionDescent2D(cross)
optimizer = ScipyMinimizer(descent.parameters(), method = 'SLSQP')
for i in range(100):
    def closure():
        optimizer.zero_grad()
        loss = descent.step()
        loss.backward()
        return loss
    loss = optimizer.step(closure)
    print(i, loss, end='       \r')
descent.plot_path()
# Out:
# 99 tensor(0.0013)       tensor(1.9554)
