# %%
import torch
from image_descent.function_descent import FunctionDescent2D
from image_descent.surfaces import *

# %%
descent = FunctionDescent2D(rosenbrock)
optimizer = torch.optim.Adam(descent.parameters(), lr=0.35)
for i in range(100):
    optimizer.zero_grad()
    loss = descent.step()
    loss.backward()
    optimizer.step()
    if i%10==0: print(i, loss, end='       \r')
descent.plot_path()
# Out:
# 90 tensor(2.5420e-06, grad_fn=<DivBackward0>)

# %%
descent = FunctionDescent2D(rastrigin)
optimizer = torch.optim.Adam(descent.parameters(), lr=0.5)
for i in range(100):
    optimizer.zero_grad()
    loss = descent()
    loss.backward()
    optimizer.step()
    print(i, loss, end='       \r')
descent.plot_path(levels=0)
# Out:
# 99 tensor(0.2469, grad_fn=<DivBackward0>)

# %%
descent = FunctionDescent2D(ackley)
optimizer = torch.optim.Adam(descent.parameters(), lr=1)
for i in range(100):
    optimizer.zero_grad()
    loss = descent()
    loss.backward()
    optimizer.step()
    print(i, loss, end='       \r')
descent.plot_path(levels=0)
# Out:
# 99 tensor(0.6793, grad_fn=<DivBackward0>)

# %%
descent = FunctionDescent2D(beale)
optimizer = torch.optim.Adam(descent.parameters(), lr=3)
for i in range(100):
    optimizer.zero_grad()
    loss = descent()
    loss.backward()
    optimizer.step()
    print(i, loss, end='       \r')
descent.plot_path()
# Out:
# 99 tensor(1.7021e-05, grad_fn=<DivBackward0>)

# %%
descent = FunctionDescent2D(booth)
optimizer = torch.optim.Adam(descent.parameters(), lr=0.6)
for i in range(100):
    optimizer.zero_grad()
    loss = descent()
    loss.backward()
    optimizer.step()
    print(i, loss, end='       \r')
descent.plot_path()
# Out:
# 99 tensor(4.7438e-06, grad_fn=<DivBackward0>)

# %%
descent = FunctionDescent2D(goldstein_prince)
optimizer = torch.optim.Adam(descent.parameters(), lr=0.2)
for i in range(100):
    optimizer.zero_grad()
    loss = descent()
    loss.backward()
    optimizer.step()
    print(i, loss, end='       \r')
descent.plot_path()
# Out:
# 99 tensor(6.8901e-06, grad_fn=<DivBackward0>)       tensor(3.4216e-05, grad_fn=<DivBackward0>)

# %%
descent = FunctionDescent2D(lambda x,y: x**2 + y**2, (-1, -0.9))
optimizer = torch.optim.Adam(descent.parameters(), lr=0.05)
for i in range(100):
    optimizer.zero_grad()
    loss = descent()
    loss.backward()
    optimizer.step()
    print(i, loss, end='       \r')
descent.plot_path()
# Out:
# 99 tensor(2.3773e-05, grad_fn=<AddBackward0>)

# %%
descent = FunctionDescent2D(sphere)
optimizer = torch.optim.Adam(descent.parameters(), lr=0.3)
for i in range(100):
    optimizer.zero_grad()
    loss = descent()
    loss.backward()
    optimizer.step()
    print(i, loss, end='       \r')
descent.plot_path()
# Out:
# 99 tensor(7.8118e-06, grad_fn=<DivBackward0>)

# %%
descent = FunctionDescent2D(cross)
optimizer = torch.optim.Adam(descent.parameters(), lr=5e-2)
for i in range(100):
    optimizer.zero_grad()
    loss = descent()
    loss.backward()
    optimizer.step()
    print(i, loss, end='       \r')
descent.plot_path()
# Out:
# 99 tensor(0.2133, grad_fn=<DivBackward0>)
