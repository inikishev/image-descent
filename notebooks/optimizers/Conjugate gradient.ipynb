# %% [markdown]
# # Conjugate gradient
# Source: https://github.com/mctorch/mctorch

# %%
from mctorch.optim import ConjugateGradient
from image_descent.function_descent import FunctionDescent2D
from image_descent.surfaces import *

# %%
descent = FunctionDescent2D(rosenbrock)
optimizer = ConjugateGradient(descent.parameters(), lr=2)
for i in range(100):
    optimizer.zero_grad()
    loss = descent.step()
    loss.backward()
    optimizer.step()
    if i%10==0: print(i, loss, end='       \r')
descent.plot_path()
# Out:
# d:\miniconda3\envs\pytorch311\Lib\site-packages\mctorch\optim\conjugate_gradient.py:113: UserWarning: This overload of add_ is deprecated:
# 	add_(Number alpha, Tensor other)
# Consider using one of the following signatures instead:
# 	add_(Tensor other, *, Number alpha) (Triggered internally at C:\cb\pytorch_1000000000000\work\torch\csrc\utils\python_arg_parser.cpp:1630.)
#   p.data.add_(group['lr'], desc_dir)
# 90 tensor(9.0264e-05, grad_fn=<DivBackward0>)

# %%
descent = FunctionDescent2D(rastrigin)
optimizer = ConjugateGradient(descent.parameters(), lr=0.3)
for i in range(100):
    optimizer.zero_grad()
    loss = descent()
    loss.backward()
    optimizer.step()
    print(i, loss, end='       \r')
descent.plot_path(levels=0)
# Out:
# 99 tensor(0.3992, grad_fn=<DivBackward0>)

# %%
descent = FunctionDescent2D(ackley)
optimizer = ConjugateGradient(descent.parameters(), lr=15)
for i in range(100):
    optimizer.zero_grad()
    loss = descent()
    loss.backward()
    optimizer.step()
    print(i, loss, end='       \r')
descent.plot_path(levels=0)
# Out:
# 99 tensor(0.9778, grad_fn=<DivBackward0>)

# %%
descent = FunctionDescent2D(beale)
optimizer = ConjugateGradient(descent.parameters(), lr=15)
for i in range(100):
    optimizer.zero_grad()
    loss = descent()
    loss.backward()
    optimizer.step()
    print(i, loss, end='       \r')
descent.plot_path()
# Out:
# 99 tensor(1.7343e-05, grad_fn=<DivBackward0>)

# %%
descent = FunctionDescent2D(booth)
optimizer = ConjugateGradient(descent.parameters(), lr=100, orth_value=1e-12)
for i in range(100):
    optimizer.zero_grad()
    loss = descent()
    loss.backward()
    optimizer.step()
    print(i, loss, end='       \r')
descent.plot_path()
# Out:
# 99 tensor(2.4292e-09, grad_fn=<DivBackward0>)

# %%
descent = FunctionDescent2D(goldstein_prince)
optimizer = ConjugateGradient(descent.parameters(), lr=40)
for i in range(100):
    optimizer.zero_grad()
    loss = descent()
    loss.backward()
    optimizer.step()
    print(i, loss, end='       \r')
descent.plot_path()
# Out:
# 99 tensor(6.2513e-06, grad_fn=<DivBackward0>)

# %%
descent = FunctionDescent2D(sphere)
optimizer = ConjugateGradient(descent.parameters(), lr=10)
for i in range(100):
    optimizer.zero_grad()
    loss = descent()
    loss.backward()
    optimizer.step()
    print(i, loss, end='       \r')
descent.plot_path()
# Out:
# 99 tensor(-1.0211e-18, grad_fn=<DivBackward0>)

# %%
descent = FunctionDescent2D(cross)
optimizer = ConjugateGradient(descent.parameters(), lr=0.05)
for i in range(100):
    optimizer.zero_grad()
    loss = descent()
    loss.backward()
    optimizer.step()
    print(i, loss, end='       \r')
descent.plot_path()
# Out:
# 99 tensor(0.2652, grad_fn=<DivBackward0>)
