# %%
import torch
from image_descent.function_descent import FunctionDescent2D
from image_descent.surfaces import *

# %%
descent = FunctionDescent2D(rosenbrock)
optimizer = torch.optim.Adam(descent.parameters(), lr=2e-1)
for i in range(1000):
    optimizer.zero_grad()
    loss = descent()
    loss.backward()
    optimizer.step()
    print(i, loss, end='       \r')
descent.plot_path()
# Out:
# 999 tensor(1.0950e-05, grad_fn=<DivBackward0>)       or(0.0001, grad_fn=<DivBackward0>)       tensor(7.8937e-05, grad_fn=<DivBackward0>)
# (<Figure size 640x480 with 2 Axes>,
#  <Axes: title={'center': 'Optimization path'}>)

# %%
descent.plot_distance_to_minimum()
# Out:
# (<Figure size 640x480 with 1 Axes>, <Axes: >)

# %%
descent = FunctionDescent2D(rastrigin)
optimizer = torch.optim.Adam(descent.parameters(), lr=1)
for i in range(1000):
    optimizer.zero_grad()
    loss = descent()
    loss.backward()
    optimizer.step()
    print(i, loss, end='       \r')
descent.plot_path(levels=0)
# Out:
# 999 tensor(0.8418, grad_fn=<DivBackward0>)       tensor(0.8391, grad_fn=<DivBackward0>)       tensor(0.8384, grad_fn=<DivBackward0>)       tensor(0.8388, grad_fn=<DivBackward0>)
# (<Figure size 640x480 with 2 Axes>,
#  <Axes: title={'center': 'Optimization path'}>)

# %%
descent = FunctionDescent2D(ackley)
optimizer = torch.optim.Adam(descent.parameters(), lr=1)
for i in range(1000):
    optimizer.zero_grad()
    loss = descent()
    loss.backward()
    optimizer.step()
    print(i, loss, end='       \r')
descent.plot_path(levels=0)
# Out:
# 999 tensor(0.7167, grad_fn=<DivBackward0>)       tensor(0.7166, grad_fn=<DivBackward0>)
# (<Figure size 640x480 with 2 Axes>,
#  <Axes: title={'center': 'Optimization path'}>)

# %%
descent = FunctionDescent2D(beale)
optimizer = torch.optim.Adam(descent.parameters(), lr=1)
for i in range(1000):
    optimizer.zero_grad()
    loss = descent()
    loss.backward()
    optimizer.step()
    print(i, loss, end='       \r')
descent.plot_path()
# Out:
# 999 tensor(6.1149e-07, grad_fn=<DivBackward0>)       ensor(6.4696e-05, grad_fn=<DivBackward0>)       tensor(6.0677e-06, grad_fn=<DivBackward0>)
# (<Figure size 640x480 with 2 Axes>,
#  <Axes: title={'center': 'Optimization path'}>)

# %%
descent = FunctionDescent2D(booth)
optimizer = torch.optim.Adam(descent.parameters(), lr=0.1)
for i in range(1000):
    optimizer.zero_grad()
    loss = descent()
    loss.backward()
    optimizer.step()
    print(i, loss, end='       \r')
descent.plot_path()
# Out:
# 999 tensor(5.1187e-08, grad_fn=<DivBackward0>)       tensor(8.2679e-05, grad_fn=<DivBackward0>)       tensor(4.2357e-06, grad_fn=<DivBackward0>)
# (<Figure size 640x480 with 2 Axes>,
#  <Axes: title={'center': 'Optimization path'}>)

# %%
descent = FunctionDescent2D(goldstein_prince)
optimizer = torch.optim.Adam(descent.parameters(), lr=0.5)
for i in range(1000):
    optimizer.zero_grad()
    loss = descent()
    loss.backward()
    optimizer.step()
    print(i, loss, end='       \r')
descent.plot_path()
# Out:
# 999 tensor(0.0002, grad_fn=<DivBackward0>)          tensor(0.0002, grad_fn=<DivBackward0>)       tensor(0.0002, grad_fn=<DivBackward0>)       tensor(0.0002, grad_fn=<DivBackward0>)
# (<Figure size 640x480 with 2 Axes>,
#  <Axes: title={'center': 'Optimization path'}>)

# %%
descent = FunctionDescent2D(lambda x,y: x**2 * y**2, (1,1))
optimizer = torch.optim.Adam(descent.parameters(), lr=2e-1)
for i in range(1000):
    optimizer.zero_grad()
    loss = descent()
    loss.backward()
    optimizer.step()
    print(i, loss, end='       \r')
descent.plot_path()
# Out:
# 999 tensor(1.2981e-08, grad_fn=<DivBackward0>)       tensor(6.3651e-08, grad_fn=<DivBackward0>)
# (<Figure size 640x480 with 2 Axes>,
#  <Axes: title={'center': 'Optimization path'}>)
